# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# canny edge detection
import cv2

# Load image
image_canny = cv2.imread('../data/train/alternaria_leaf_spot/000414.jpg', cv2.IMREAD_GRAYSCALE)

# Apply Canny edge detection
edges = cv2.Canny(image_canny, 100, 200)  # Adjust threshold values as needed

# Display results
#cv2.imshow('Original Image', image)
#cv2.imshow('Canny Edge Detection', edges)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image_canny, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(edges, cmap='gray')
plt.title('Canny Edge Detection')
plt.axis('off')

plt.show()

# %% [markdown]
# # -------------------------------------------------

# %%
# sobel edge detection

image = cv2.imread('../data/train/alternaria_leaf_spot/000414.jpg', cv2.IMREAD_GRAYSCALE)

sobelx = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
sobely = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)
sobel_combined = cv2.sqrt(cv2.addWeighted(cv2.pow(sobelx, 2.0), 1.0, cv2.pow(sobely, 2.0), 1.0, 0.0))


plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(sobel_combined, cmap='gray')
plt.title('Sobel Edge Detection')
plt.axis('off')

plt.show()

# %%
# Sobel 2

# sobel edge detection 2

image_sob = cv2.imread('../data/train/bacterial_spot/0a64655c-4052-4e5f-a696-2a6cf25d10c9___GCREC_Bact.Sp 6017.JPG', cv2.IMREAD_GRAYSCALE)

sobelx = cv2.Sobel(image_sob, cv2.CV_64F, 1, 0, ksize=3)
sobely = cv2.Sobel(image_sob, cv2.CV_64F, 0, 1, ksize=3)
sobel_combined2 = cv2.sqrt(cv2.addWeighted(cv2.pow(sobelx, 2.0), 1.0, cv2.pow(sobely, 2.0), 1.0, 0.0))


plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image_sob, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(sobel_combined2, cmap='gray')
plt.title('Sobel Edge Detection2')
plt.axis('off')

plt.show()

# %%
# Laplacian operator

import cv2

# Load image
image_lap = cv2.imread('../data/train/alternaria_leaf_spot/000414.jpg', cv2.IMREAD_GRAYSCALE)

# Apply Laplacian operator
laplacian = cv2.Laplacian(image_lap, cv2.CV_64F)

# Display results
#cv2.imshow('Original Image', image)
#cv2.imshow('Laplacian Edge Detection', laplacian)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image_lap, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(laplacian, cmap='gray')
plt.title('Laplacian Edge Detection')
plt.axis('off')

plt.show()

# %%
# Laplacian operator on another sample image

import cv2

# Load image
image_lap2 = cv2.imread('../data/train/bacterial_spot/0a64655c-4052-4e5f-a696-2a6cf25d10c9___GCREC_Bact.Sp 6017.JPG', cv2.IMREAD_GRAYSCALE)

# Apply Laplacian operator
laplacian = cv2.Laplacian(image_lap2, cv2.CV_64F)

# Display results
#cv2.imshow('Original Image', image)
#cv2.imshow('Laplacian Edge Detection', laplacian)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image_lap2, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(laplacian, cmap='gray')
plt.title('Laplacian Edge Detection')
plt.axis('off')

plt.show()

# %%
import cv2

# Load the image
image_yes = cv2.imread('../data/train/alternaria_leaf_spot/000414.jpg')

# Resize the image (optional)
#resized_image = cv2.resize(image, (800, 600)) 

# Convert the image to grayscale
gray_image = cv2.cvtColor(image_yes, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur to reduce noise
blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)  #kernel size could be adjusted as needed


# Perform edge detection (e.g., using Canny edge detector)
edges_yes = cv2.Canny(blurred_image, 50, 150)  # Adjustable threshold values


# Display the original image and the detected edges
#cv2.imshow('Original Image', resized_image)
#cv2.imshow('Detected Edges', edges)
#cv2.waitKey(0)tou
#cv2.destroyAllWindows()


# Display the original image and the detected edges
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image_yes, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(edges_yes, cmap='gray')
plt.title('Detected Edges')
plt.axis('off')

plt.show()
